# %% [markdown]
# # Deep Learning | Perceptrons and MLP for Classification

# %% [markdown]
# ### Dataset: Iris | Framework: Keras (Tensorflow)

# %% [markdown]
# ## 🔹 1. Setup & Data Loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
# Load dataset
iris = load_iris()

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# :Missing Attribute Values: None
# :Class Distribution: 33.3% for each of 3 classes.
# :Creator: R.A. Fisher
# :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
# :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. dropdown:: References
#
#   - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#     Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#     Mathematical Statistics" (John Wiley, NY, 1950).
#   - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#     (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#   - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#     Structure and Classification Rule for Recognition in Partially Exposed
#     Environments".  IEEE Transactions on Pattern Analysis and Machine
#     Intelligence, Vol. PAMI-2, No. 1, 67-71.
#   - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#     on Information Theory, May 1972, 431-433.
#   - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#     conceptual clustering system finds 3 classes in the data.
#   - Many, many more ...

# %%
X = iris.data
y = iris.target

# %%
type(X)
# Out:
# numpy.ndarray

# %%
feature_names = iris.feature_names
target_names = iris.target_names

# %%
type(iris)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# - type(iris)
# - sklearn.utils._branch.Bunch -> tells us that data is in dictionary shape

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %% [markdown]
# ### Making a dataframe from numpy
#
# - currently the data is in numpy ndarray
# - to change, you can do

# %%
y_cat = to_categorical(y)

# %%
df = pd.DataFrame(data=X, columns=feature_names)
df['target']= y
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 🔹 2. MLP Basics: First 2 features (Iris)

# %% [markdown]
# ### ✅ Preprocess the dataset

# %%
X_vis = X[:, :2]

# %%
# Scale inputs
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.26418478e+00,  7.88807586e-01, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.26418478e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.44707648e+00],
#        [-1.87002413e+00, -1.31979479e-01, -1.51073881e+00,
#         -1.44707648e+00],
#        [-5.25060772e-02,  2.16998818e+00, -1.45390138e+00,
#         -1.31544430e+00],
#        [-1.73673948e-01,  3.09077525e+00, -1.28338910e+00,
#         -1.05217993e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.39706395e+00,
#         -1.05217993e+00],
#        [-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.73673948e-01,  1.70959465e+00, -1.16971425e+00,
#         -1.18381211e+00],
#        [-9.00681170e-01,  1.70959465e+00, -1.28338910e+00,
#         -1.18381211e+00],
#        [-5.37177559e-01,  7.88807586e-01, -1.16971425e+00,
#         -1.31544430e+00],
#        [-9.00681170e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  1.24920112e+00, -1.56757623e+00,
#         -1.31544430e+00],
#        [-9.00681170e-01,  5.58610819e-01, -1.16971425e+00,
#         -9.20547742e-01],
#        [-1.26418478e+00,  7.88807586e-01, -1.05603939e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00, -1.31979479e-01, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.22655167e+00,
#         -1.05217993e+00],
#        [-7.79513300e-01,  1.01900435e+00, -1.28338910e+00,
#         -1.31544430e+00],
#        [-7.79513300e-01,  7.88807586e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.26418478e+00,  9.82172869e-02, -1.22655167e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  7.88807586e-01, -1.28338910e+00,
#         -1.05217993e+00],
#        [-7.79513300e-01,  2.40018495e+00, -1.28338910e+00,
#         -1.44707648e+00],
#        [-4.16009689e-01,  2.63038172e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  3.28414053e-01, -1.45390138e+00,
#         -1.31544430e+00],
#        [-4.16009689e-01,  1.01900435e+00, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.44707648e+00],
#        [-1.74885626e+00, -1.31979479e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-9.00681170e-01,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.01900435e+00, -1.39706395e+00,
#         -1.18381211e+00],
#        [-1.62768839e+00, -1.74335684e+00, -1.39706395e+00,
#         -1.18381211e+00],
#        [-1.74885626e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.01900435e+00, -1.22655167e+00,
#         -7.88915558e-01],
#        [-9.00681170e-01,  1.70959465e+00, -1.05603939e+00,
#         -1.05217993e+00],
#        [-1.26418478e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-9.00681170e-01,  1.70959465e+00, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  3.28414053e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-6.58345429e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  5.58610819e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [ 1.40150837e+00,  3.28414053e-01,  5.35408562e-01,
#          2.64141916e-01],
#        [ 6.74501145e-01,  3.28414053e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [ 1.28034050e+00,  9.82172869e-02,  6.49083415e-01,
#          3.95774101e-01],
#        [-4.16009689e-01, -1.74335684e+00,  1.37546573e-01,
#          1.32509732e-01],
#        [ 7.95669016e-01, -5.92373012e-01,  4.78571135e-01,
#          3.95774101e-01],
#        [-1.73673948e-01, -5.92373012e-01,  4.21733708e-01,
#          1.32509732e-01],
#        [ 5.53333275e-01,  5.58610819e-01,  5.35408562e-01,
#          5.27406285e-01],
#        [-1.14301691e+00, -1.51316008e+00, -2.60315415e-01,
#         -2.62386821e-01],
#        [ 9.16836886e-01, -3.62176246e-01,  4.78571135e-01,
#          1.32509732e-01],
#        [-7.79513300e-01, -8.22569778e-01,  8.07091462e-02,
#          2.64141916e-01],
#        [-1.02184904e+00, -2.43394714e+00, -1.46640561e-01,
#         -2.62386821e-01],
#        [ 6.86617933e-02, -1.31979479e-01,  2.51221427e-01,
#          3.95774101e-01],
#        [ 1.89829664e-01, -1.97355361e+00,  1.37546573e-01,
#         -2.62386821e-01],
#        [ 3.10997534e-01, -3.62176246e-01,  5.35408562e-01,
#          2.64141916e-01],
#        [-2.94841818e-01, -3.62176246e-01, -8.98031345e-02,
#          1.32509732e-01],
#        [ 1.03800476e+00,  9.82172869e-02,  3.64896281e-01,
#          2.64141916e-01],
#        [-2.94841818e-01, -1.31979479e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [-5.25060772e-02, -8.22569778e-01,  1.94384000e-01,
#         -2.62386821e-01],
#        [ 4.32165405e-01, -1.97355361e+00,  4.21733708e-01,
#          3.95774101e-01],
#        [-2.94841818e-01, -1.28296331e+00,  8.07091462e-02,
#         -1.30754636e-01],
#        [ 6.86617933e-02,  3.28414053e-01,  5.92245988e-01,
#          7.90670654e-01],
#        [ 3.10997534e-01, -5.92373012e-01,  1.37546573e-01,
#          1.32509732e-01],
#        [ 5.53333275e-01, -1.28296331e+00,  6.49083415e-01,
#          3.95774101e-01],
#        [ 3.10997534e-01, -5.92373012e-01,  5.35408562e-01,
#          8.77547895e-04],
#        [ 6.74501145e-01, -3.62176246e-01,  3.08058854e-01,
#          1.32509732e-01],
#        [ 9.16836886e-01, -1.31979479e-01,  3.64896281e-01,
#          2.64141916e-01],
#        [ 1.15917263e+00, -5.92373012e-01,  5.92245988e-01,
#          2.64141916e-01],
#        [ 1.03800476e+00, -1.31979479e-01,  7.05920842e-01,
#          6.59038469e-01],
#        [ 1.89829664e-01, -3.62176246e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [-1.73673948e-01, -1.05276654e+00, -1.46640561e-01,
#         -2.62386821e-01],
#        [-4.16009689e-01, -1.51316008e+00,  2.38717193e-02,
#         -1.30754636e-01],
#        [-4.16009689e-01, -1.51316008e+00, -3.29657076e-02,
#         -2.62386821e-01],
#        [-5.25060772e-02, -8.22569778e-01,  8.07091462e-02,
#          8.77547895e-04],
#        [ 1.89829664e-01, -8.22569778e-01,  7.62758269e-01,
#          5.27406285e-01],
#        [-5.37177559e-01, -1.31979479e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [ 1.89829664e-01,  7.88807586e-01,  4.21733708e-01,
#          5.27406285e-01],
#        [ 1.03800476e+00,  9.82172869e-02,  5.35408562e-01,
#          3.95774101e-01],
#        [ 5.53333275e-01, -1.74335684e+00,  3.64896281e-01,
#          1.32509732e-01],
#        [-2.94841818e-01, -1.31979479e-01,  1.94384000e-01,
#          1.32509732e-01],
#        [-4.16009689e-01, -1.28296331e+00,  1.37546573e-01,
#          1.32509732e-01],
#        [-4.16009689e-01, -1.05276654e+00,  3.64896281e-01,
#          8.77547895e-04],
#        [ 3.10997534e-01, -1.31979479e-01,  4.78571135e-01,
#          2.64141916e-01],
#        [-5.25060772e-02, -1.05276654e+00,  1.37546573e-01,
#          8.77547895e-04],
#        [-1.02184904e+00, -1.74335684e+00, -2.60315415e-01,
#         -2.62386821e-01],
#        [-2.94841818e-01, -8.22569778e-01,  2.51221427e-01,
#          1.32509732e-01],
#        [-1.73673948e-01, -1.31979479e-01,  2.51221427e-01,
#          8.77547895e-04],
#        [-1.73673948e-01, -3.62176246e-01,  2.51221427e-01,
#          1.32509732e-01],
#        [ 4.32165405e-01, -3.62176246e-01,  3.08058854e-01,
#          1.32509732e-01],
#        [-9.00681170e-01, -1.28296331e+00, -4.30827696e-01,
#         -1.30754636e-01],
#        [-1.73673948e-01, -5.92373012e-01,  1.94384000e-01,
#          1.32509732e-01],
#        [ 5.53333275e-01,  5.58610819e-01,  1.27429511e+00,
#          1.71209594e+00],
#        [-5.25060772e-02, -8.22569778e-01,  7.62758269e-01,
#          9.22302838e-01],
#        [ 1.52267624e+00, -1.31979479e-01,  1.21745768e+00,
#          1.18556721e+00],
#        [ 5.53333275e-01, -3.62176246e-01,  1.04694540e+00,
#          7.90670654e-01],
#        [ 7.95669016e-01, -1.31979479e-01,  1.16062026e+00,
#          1.31719939e+00],
#        [ 2.12851559e+00, -1.31979479e-01,  1.61531967e+00,
#          1.18556721e+00],
#        [-1.14301691e+00, -1.28296331e+00,  4.21733708e-01,
#          6.59038469e-01],
#        [ 1.76501198e+00, -3.62176246e-01,  1.44480739e+00,
#          7.90670654e-01],
#        [ 1.03800476e+00, -1.28296331e+00,  1.16062026e+00,
#          7.90670654e-01],
#        [ 1.64384411e+00,  1.24920112e+00,  1.33113254e+00,
#          1.71209594e+00],
#        [ 7.95669016e-01,  3.28414053e-01,  7.62758269e-01,
#          1.05393502e+00],
#        [ 6.74501145e-01, -8.22569778e-01,  8.76433123e-01,
#          9.22302838e-01],
#        [ 1.15917263e+00, -1.31979479e-01,  9.90107977e-01,
#          1.18556721e+00],
#        [-1.73673948e-01, -1.28296331e+00,  7.05920842e-01,
#          1.05393502e+00],
#        [-5.25060772e-02, -5.92373012e-01,  7.62758269e-01,
#          1.58046376e+00],
#        [ 6.74501145e-01,  3.28414053e-01,  8.76433123e-01,
#          1.44883158e+00],
#        [ 7.95669016e-01, -1.31979479e-01,  9.90107977e-01,
#          7.90670654e-01],
#        [ 2.24968346e+00,  1.70959465e+00,  1.67215710e+00,
#          1.31719939e+00],
#        [ 2.24968346e+00, -1.05276654e+00,  1.78583195e+00,
#          1.44883158e+00],
#        [ 1.89829664e-01, -1.97355361e+00,  7.05920842e-01,
#          3.95774101e-01],
#        [ 1.28034050e+00,  3.28414053e-01,  1.10378283e+00,
#          1.44883158e+00],
#        [-2.94841818e-01, -5.92373012e-01,  6.49083415e-01,
#          1.05393502e+00],
#        [ 2.24968346e+00, -5.92373012e-01,  1.67215710e+00,
#          1.05393502e+00],
#        [ 5.53333275e-01, -8.22569778e-01,  6.49083415e-01,
#          7.90670654e-01],
#        [ 1.03800476e+00,  5.58610819e-01,  1.10378283e+00,
#          1.18556721e+00],
#        [ 1.64384411e+00,  3.28414053e-01,  1.27429511e+00,
#          7.90670654e-01],
#        [ 4.32165405e-01, -5.92373012e-01,  5.92245988e-01,
#          7.90670654e-01],
#        [ 3.10997534e-01, -1.31979479e-01,  6.49083415e-01,
#          7.90670654e-01],
#        [ 6.74501145e-01, -5.92373012e-01,  1.04694540e+00,
#          1.18556721e+00],
#        [ 1.64384411e+00, -1.31979479e-01,  1.16062026e+00,
#          5.27406285e-01],
#        [ 1.88617985e+00, -5.92373012e-01,  1.33113254e+00,
#          9.22302838e-01],
#        [ 2.49201920e+00,  1.70959465e+00,  1.50164482e+00,
#          1.05393502e+00],
#        [ 6.74501145e-01, -5.92373012e-01,  1.04694540e+00,
#          1.31719939e+00],
#        [ 5.53333275e-01, -5.92373012e-01,  7.62758269e-01,
#          3.95774101e-01],
#        [ 3.10997534e-01, -1.05276654e+00,  1.04694540e+00,
#          2.64141916e-01],
#        [ 2.24968346e+00, -1.31979479e-01,  1.33113254e+00,
#          1.44883158e+00],
#        [ 5.53333275e-01,  7.88807586e-01,  1.04694540e+00,
#          1.58046376e+00],
#        [ 6.74501145e-01,  9.82172869e-02,  9.90107977e-01,
#          7.90670654e-01],
#        [ 1.89829664e-01, -1.31979479e-01,  5.92245988e-01,
#          7.90670654e-01],
#        [ 1.28034050e+00,  9.82172869e-02,  9.33270550e-01,
#          1.18556721e+00],
#        [ 1.03800476e+00,  9.82172869e-02,  1.04694540e+00,
#          1.58046376e+00],
#        [ 1.28034050e+00,  9.82172869e-02,  7.62758269e-01,
#          1.44883158e+00],
#        [-5.25060772e-02, -8.22569778e-01,  7.62758269e-01,
#          9.22302838e-01],
#        [ 1.15917263e+00,  3.28414053e-01,  1.21745768e+00,
#          1.44883158e+00],
#        [ 1.03800476e+00,  5.58610819e-01,  1.10378283e+00,
#          1.71209594e+00],
#        [ 1.03800476e+00, -1.31979479e-01,  8.19595696e-01,
#          1.44883158e+00],
#        [ 5.53333275e-01, -1.28296331e+00,  7.05920842e-01,
#          9.22302838e-01],
#        [ 7.95669016e-01, -1.31979479e-01,  8.19595696e-01,
#          1.05393502e+00],
#        [ 4.32165405e-01,  7.88807586e-01,  9.33270550e-01,
#          1.44883158e+00],
#        [ 6.86617933e-02, -1.31979479e-01,  7.62758269e-01,
#          7.90670654e-01]])

# %%
X_scaled.shape
# Out:
# (150, 4)

# %%
y_cat.shape
# Out:
# (150, 3)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_cat, test_size=0.2, random_state=42)

# %% [markdown]
# ### ✅ Visualization: Input Space

# %%
df_plot = pd.DataFrame(X_scaled, columns=feature_names)
df_plot['target'] = y
sns.pairplot(df_plot, hue='target', palette='Set2', height=3)
plt.suptitle("Pairplot of all features", y=1.02)
plt.show()

# %% [markdown]
# ### EDA insights
#
# - class (Iris-Setosa) 0 is well separated
# - Iris versicolour and Iris virginica are mixed
# - We could remove the latter two but I am going to try with all three

# %% [markdown]
# ### ✅ Baseline Model: No Hidden Layer

# %%
model_linear = Sequential([
    InputLayer(shape=(4,)),

    # 4 is the number of input features 
    
    Dense(3, activation='softmax')
    
    # 3 neurons = 3 classes
    # softmax for multiclass
])

# %%
model_linear.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# optimizer for gradient descent
# cat cross entropy for classes

# %%
model_linear.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 3)              │            15 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15 (60.00 B)
#  Trainable params: 15 (60.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Param explanation
#
# 4 input features * 3 neurons = 12 + 3(biases, each neuron having its own) = 15

# %%
history_linear = model_linear.fit(X_train, y_train, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4156 - loss: 1.0928
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4096 - loss: 1.0807
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4338 - loss: 1.0645
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4204 - loss: 1.0842
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4694 - loss: 0.9960
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4642 - loss: 1.0012
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4308 - loss: 1.0161
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4487 - loss: 0.9898
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4112 - loss: 1.0047
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4746 - loss: 0.9877
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4883 - loss: 0.9861
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5146 - loss: 0.9515
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5213 - loss: 0.9506
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4850 - loss: 0.9554
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5183 - loss: 0.9508
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5100 - loss: 0.9337
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5433 - loss: 0.9342
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5394 - loss: 0.8999
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5021 - loss: 0.9613
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5073 - loss: 0.9238
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5563 - loss: 0.8968
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5362 - loss: 0.8849
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5581 - loss: 0.8531
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5029 - loss: 0.8865
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5269 - loss: 0.8635
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5227 - loss: 0.8505
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5540 - loss: 0.8334
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5008 - loss: 0.8534
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5185 - loss: 0.8553
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4854 - loss: 0.8594
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5458 - loss: 0.8131
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5242 - loss: 0.8342
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5648 - loss: 0.8062
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6198 - loss: 0.7767
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5781 - loss: 0.8026
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6260 - loss: 0.7640
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6198 - loss: 0.7823
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5604 - loss: 0.7822
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5779 - loss: 0.7744
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5877 - loss: 0.7730
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6171 - loss: 0.7451
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6258 - loss: 0.7533
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6498 - loss: 0.7479
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6000 - loss: 0.7456
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6571 - loss: 0.7480
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6590 - loss: 0.7306
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6277 - loss: 0.7372
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6477 - loss: 0.7350
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6252 - loss: 0.7396
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6483 - loss: 0.7512

# %%
# Evaluation
y_pred_linear = np.argmax(model_linear.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step

# %%
print("Accuracy (No Hidden Layer):", accuracy_score(y_true, y_pred_linear))
# Out:
# Accuracy (No Hidden Layer): 0.7

# %%
ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred_linear), display_labels=target_names).plot()
plt.title("Confusion Matrix – Linear Classifier")
plt.show()

# %% [markdown]
# ### ✅ MLP with Hidden Layer

# %%
model_mlp = Sequential([
    InputLayer(shape=(4,)),
    Dense(8, activation='relu'),
    Dense(3, activation='softmax')
])

model_mlp.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_mlp.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 67 (268.00 B)
#  Trainable params: 67 (268.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Params explanation
#
# 4(input) * 8(neurons) = 32 + 8 = 40
# 8 (input) * 3(neurons) = 24 + 3 = 27

# %%
history_mlp = model_mlp.fit(X_train, y_train, epochs=50, verbose=0)

# %%
y_pred_mlp = np.argmax(model_mlp.predict(X_test), axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step

# %%
print("Accuracy (With Hidden Layer):", accuracy_score(y_true, y_pred_mlp))
# Out:
# Accuracy (With Hidden Layer): 0.9

# %%
ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred_mlp), display_labels=target_names).plot()
plt.title("Confusion Matrix – MLP")
plt.show()

# %% [markdown]
# ## 🔹 3. Visualizing Decision Boundaries

# %%
def plot_decision_boundary(model, X, y, title="Decision Boundary"):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                           np.arange(y_min, y_max, 0.02))
    grid = np.c_[xx.ravel(), yy.ravel()]
    probs = model.predict(grid)
    preds = np.argmax(probs, axis=1).reshape(xx.shape)

    plt.contourf(xx, yy, preds, alpha=0.4, cmap='Pastel2')
    plt.scatter(X[:, 0], X[:, 1], c=np.argmax(y, axis=1), edgecolors='k', cmap='Dark2')
    plt.title(title)
    plt.xlabel(feature_names[0])
    plt.ylabel(feature_names[1])
    plt.show()

# %%
X_scaled.shape
# Out:
# (150, 4)

# %%
y_cat.shape
# Out:
# (150, 3)

# %%
model_linear
# Out:
# <Sequential name=sequential_1, built=True>

# %%
# Decision boundaries
plot_decision_boundary(model_linear, X_scaled[:,:2], y_cat, "Linear Model Decision Boundary")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[61], line 2
#       1 # Decision boundaries
# ----> 2 plot_decision_boundary(model_linear, X_scaled[:,:2], y_cat, "Linear Model Decision Boundary")
#
# Cell In[52], line 7, in plot_decision_boundary(model, X, y, title)
#       4 xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
#       5                      np.arange(y_min, y_max, 0.02))
#       6 grid = np.c_[xx.ravel(), yy.ravel()]
# ----> 7 probs = model.predict(grid)
#       8 preds = np.argmax(probs, axis=1).reshape(xx.shape)
#      10 plt.contourf(xx, yy, preds, alpha=0.4, cmap='Pastel2')
#
# File c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_1_1/dense_1_1/BiasAdd defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\asyncio\base_events.py", line 608, in run_forever
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\asyncio\base_events.py", line 1936, in _run_once
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\asyncio\events.py", line 84, in _run
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\IPython\core\interactiveshell.py", line 3047, in run_cell
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\IPython\core\interactiveshell.py", line 3102, in _run_cell
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\IPython\core\interactiveshell.py", line 3306, in run_cell_async
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\IPython\core\interactiveshell.py", line 3489, in run_ast_nodes
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\IPython\core\interactiveshell.py", line 3549, in run_code
#
#   File "C:\Users\Zehra\AppData\Local\Temp\ipykernel_25864\1679525136.py", line 2, in <module>
#
#   File "C:\Users\Zehra\AppData\Local\Temp\ipykernel_25864\1977314983.py", line 7, in plot_decision_boundary
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 560, in predict
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 259, in one_step_on_data_distributed
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 249, in one_step_on_data
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 104, in predict_step
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\layers\layer.py", line 910, in __call__
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\ops\operation.py", line 58, in __call__
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\models\sequential.py", line 221, in call
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\ops\function.py", line 171, in _run_through_graph
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\models\functional.py", line 643, in call
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\layers\layer.py", line 910, in __call__
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\ops\operation.py", line 58, in __call__
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\layers\core\dense.py", line 146, in call
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\ops\numpy.py", line 237, in add
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\backend\tensorflow\sparse.py", line 493, in sparse_wrapper
#
#   File "c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 129, in add
#
# Matrix size-incompatible: In[0]: [32,2], In[1]: [4,3]
# 	 [[{{node sequential_1_1/dense_1_1/BiasAdd}}]] [Op:__inference_one_step_on_data_distributed_9429]

# %%
plot_decision_boundary(model_mlp, X_scaled, y_cat, "MLP Decision Boundary")
# Out:
# 3759/3759 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step

# %% [markdown]
# ## 🔹 3. MLP Using All 4 Features of Iris Dataset

# %% [markdown]
# ### ✅ Prepare Full Feature Input

# %%
# Reload original features (all 4)
X_full = iris.data

# Standardize all 4 features
scaler_full = StandardScaler()
X_full_scaled = scaler_full.fit_transform(X_full)

# Split again
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_full_scaled, y_cat, test_size=0.2, random_state=42)

# %% [markdown]
# ### ✅ Define and Train MLP

# %%
model_full = Sequential([
    InputLayer(shape=(4,)),
    Dense(10, activation='relu'),
    Dense(6, activation='relu'),
    Dense(3, activation='softmax')
])

model_full.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_full.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 10)             │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │            66 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 3)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137 (548.00 B)
#  Trainable params: 137 (548.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history_full = model_full.fit(X_train_f, y_train_f, epochs=300, verbose=0)

# %% [markdown]
# ### ✅ Evaluate and Visualize

# %%
# Predict
y_pred_full = np.argmax(model_full.predict(X_test_f), axis=1)
y_true_full = np.argmax(y_test_f, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step

# %%
# Accuracy and confusion matrix
print("Accuracy (All Features MLP):", accuracy_score(y_true_full, y_pred_full))
# Out:
# Accuracy (All Features MLP): 1.0

# %%
ConfusionMatrixDisplay(confusion_matrix(y_true_full, y_pred_full), display_labels=target_names).plot()
plt.title("Confusion Matrix – MLP with All 4 Features")
plt.show()

# %% [markdown]
# ### ✅ Plot Learning Curves

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Accuracy plot
axs[0].plot(history_full.history['accuracy'], label='Train Acc')
axs[0].set_title('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()
axs[0].grid(True)

# Loss plot
axs[1].plot(history_full.history['loss'], label='Train Loss')
axs[1].set_title('Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔹 4. Update Model Training (with Validation Data)

# %%
model_full_2 = Sequential([
    InputLayer(shape=(4,)),
    Dense(10, activation='relu'),
    Dense(6, activation='relu'),
    Dense(3, activation='softmax')
])

model_full_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_full_2.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 10)             │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 6)              │            66 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 3)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137 (548.00 B)
#  Trainable params: 137 (548.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X_train_f.shape
# Out:
# (120, 4)

# %%
# Train with validation split
history_full_2 = model_full_2.fit(
    X_train_f, y_train_f,
    validation_split=0.2,
    epochs=300,
    verbose=1
)
# Out:
# Epoch 1/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.2930 - loss: 1.0625 - val_accuracy: 0.4167 - val_loss: 0.9975
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2773 - loss: 1.0553 - val_accuracy: 0.4583 - val_loss: 0.9892
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3008 - loss: 1.0374 - val_accuracy: 0.4583 - val_loss: 0.9818
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3229 - loss: 1.0207 - val_accuracy: 0.4583 - val_loss: 0.9741
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2799 - loss: 1.0241 - val_accuracy: 0.4583 - val_loss: 0.9664
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3346 - loss: 1.0063 - val_accuracy: 0.4583 - val_loss: 0.9585
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3464 - loss: 1.0001 - val_accuracy: 0.5000 - val_loss: 0.9512
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3737 - loss: 0.9944 - val_accuracy: 0.5833 - val_loss: 0.9440
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3555 - loss: 0.9901 - val_accuracy: 0.5833 - val_loss: 0.9375
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4427 - loss: 0.9762 - val_accuracy: 0.6667 - val_loss: 0.9304
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3789 - loss: 0.9860 - val_accuracy: 0.7083 - val_loss: 0.9236
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4388 - loss: 0.9692 - val_accuracy: 0.7083 - val_loss: 0.9162
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4036 - loss: 0.9678 - val_accuracy: 0.7500 - val_loss: 0.9084
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4414 - loss: 0.9559 - val_accuracy: 0.7500 - val_loss: 0.9004
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4336 - loss: 0.9461 - val_accuracy: 0.7917 - val_loss: 0.8921
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3789 - loss: 0.9493 - val_accuracy: 0.7917 - val_loss: 0.8835
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4518 - loss: 0.9356 - val_accuracy: 0.7917 - val_loss: 0.8744
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4284 - loss: 0.9344 - val_accuracy: 0.7917 - val_loss: 0.8657
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4766 - loss: 0.9157 - val_accuracy: 0.7917 - val_loss: 0.8565
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4818 - loss: 0.9035 - val_accuracy: 0.7917 - val_loss: 0.8470
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5260 - loss: 0.9032 - val_accuracy: 0.8333 - val_loss: 0.8376
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6081 - loss: 0.8888 - val_accuracy: 0.8750 - val_loss: 0.8279
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6224 - loss: 0.8761 - val_accuracy: 0.8750 - val_loss: 0.8178
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7240 - loss: 0.8776 - val_accuracy: 0.9167 - val_loss: 0.8082
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7617 - loss: 0.8738 - val_accuracy: 0.9167 - val_loss: 0.7984
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7734 - loss: 0.8551 - val_accuracy: 0.9167 - val_loss: 0.7884
# Epoch 27/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7969 - loss: 0.8419 - val_accuracy: 0.9167 - val_loss: 0.7779
# Epoch 28/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7617 - loss: 0.8411 - val_accuracy: 0.9167 - val_loss: 0.7681
# Epoch 29/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.
300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9896 - loss: 0.0699 - val_accuracy: 0.9583 - val_loss: 0.0916
# Epoch 286/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9779 - loss: 0.0789 - val_accuracy: 0.9583 - val_loss: 0.0927
# Epoch 287/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9948 - loss: 0.0741 - val_accuracy: 0.9583 - val_loss: 0.0919
# Epoch 288/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9909 - loss: 0.0792 - val_accuracy: 0.9583 - val_loss: 0.0922
# Epoch 289/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9831 - loss: 0.0746 - val_accuracy: 0.9583 - val_loss: 0.0925
# Epoch 290/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9948 - loss: 0.0728 - val_accuracy: 0.9583 - val_loss: 0.0922
# Epoch 291/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9948 - loss: 0.0733 - val_accuracy: 0.9583 - val_loss: 0.0916
# Epoch 292/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9831 - loss: 0.0923 - val_accuracy: 0.9583 - val_loss: 0.0924
# Epoch 293/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9948 - loss: 0.0854 - val_accuracy: 0.9583 - val_loss: 0.0917
# Epoch 294/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9831 - loss: 0.0672 - val_accuracy: 0.9583 - val_loss: 0.0918
# Epoch 295/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9909 - loss: 0.0801 - val_accuracy: 0.9583 - val_loss: 0.0908
# Epoch 296/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9948 - loss: 0.0783 - val_accuracy: 0.9583 - val_loss: 0.0905
# Epoch 297/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9948 - loss: 0.0639 - val_accuracy: 0.9583 - val_loss: 0.0899
# Epoch 298/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9831 - loss: 0.0878 - val_accuracy: 0.9583 - val_loss: 0.0900
# Epoch 299/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9909 - loss: 0.0685 - val_accuracy: 0.9583 - val_loss: 0.0901
# Epoch 300/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9948 - loss: 0.0805 - val_accuracy: 0.9583 - val_loss: 0.0900

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Accuracy plot
axs[0].plot(history_full_2.history['accuracy'], label='Train Acc')
axs[0].plot(history_full_2.history['val_accuracy'], label='Val Acc', linestyle='--')
axs[0].set_title('Accuracy (Train vs Va|l)')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()
axs[0].grid(True)

# Loss plot
axs[1].plot(history_full_2.history['loss'], label='Train Loss')
axs[1].plot(history_full_2.history['val_loss'], label='Val Loss', linestyle='--')
axs[1].set_title('Loss (Train vs Val)')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Predict
y_pred_full_2 = np.argmax(model_full_2.predict(X_test_f), axis=1)

# Accuracy and confusion matrix
print("Accuracy (All Features MLP):", accuracy_score(y_true_full, y_pred_full_2))

ConfusionMatrixDisplay(confusion_matrix(y_true_full, y_pred_full_2), display_labels=target_names).plot()
plt.title("Confusion Matrix – MLP with All 4 Features")
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001FBD07B0860> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Accuracy (All Features MLP): 1.0

# %% [markdown]
# ## 🔹 5. Early Stopping and Model Checkpointing

# %%
model_full_3 = Sequential([
    Dense(10, input_shape=(4,), activation='relu'),
    Dense(6, activation='relu'),
    Dense(3, activation='softmax')
])

model_full_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model_full_3.summary()
# Out:
# c:\Users\Zehra\anaconda3\envs\env_for_eda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 10)             │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 6)              │            66 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 3)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137 (548.00 B)
#  Trainable params: 137 (548.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### ✅ Set Up Callbacks

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,  # Recover best weights, not just stop
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_model_iris.keras',  # File name (SavedModel format)
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# %% [markdown]
# ### ✅ Train with Callbacks

# %%
history_full_3 = model_full_3.fit(
    X_train_f, y_train_f,
    validation_split=0.2,
    epochs=200,
    callbacks=[early_stop, checkpoint],
    verbose=2
)
# Out:
# Epoch 1/200
#
# Epoch 1: val_loss improved from inf to 1.08281, saving model to best_model_iris.keras
# 3/3 - 2s - 729ms/step - accuracy: 0.1771 - loss: 1.1092 - val_accuracy: 0.3333 - val_loss: 1.0828
# Epoch 2/200
#
# Epoch 2: val_loss improved from 1.08281 to 1.07565, saving model to best_model_iris.keras
# 3/3 - 0s - 58ms/step - accuracy: 0.1875 - loss: 1.1008 - val_accuracy: 0.3333 - val_loss: 1.0756
# Epoch 3/200
#
# Epoch 3: val_loss improved from 1.07565 to 1.06799, saving model to best_model_iris.keras
# 3/3 - 0s - 57ms/step - accuracy: 0.2083 - loss: 1.0925 - val_accuracy: 0.3750 - val_loss: 1.0680
# Epoch 4/200
#
# Epoch 4: val_loss improved from 1.06799 to 1.06003, saving model to best_model_iris.keras
# 3/3 - 0s - 64ms/step - accuracy: 0.2500 - loss: 1.0839 - val_accuracy: 0.4583 - val_loss: 1.0600
# Epoch 5/200
#
# Epoch 5: val_loss improved from 1.06003 to 1.05139, saving model to best_model_iris.keras
# 3/3 - 0s - 57ms/step - accuracy: 0.3333 - loss: 1.0751 - val_accuracy: 0.5000 - val_loss: 1.0514
# Epoch 6/200
#
# Epoch 6: val_loss improved from 1.05139 to 1.04248, saving model to best_model_iris.keras
# 3/3 - 0s - 55ms/step - accuracy: 0.4062 - loss: 1.0670 - val_accuracy: 0.5000 - val_loss: 1.0425
# Epoch 7/200
#
# Epoch 7: val_loss improved from 1.04248 to 1.03342, saving model to best_model_iris.keras
# 3/3 - 0s - 62ms/step - accuracy: 0.4896 - loss: 1.0587 - val_accuracy: 0.5417 - val_loss: 1.0334
# Epoch 8/200
#
# Epoch 8: val_loss improved from 1.03342 to 1.02419, saving model to best_model_iris.keras
# 3/3 - 0s - 52ms/step - accuracy: 0.5417 - loss: 1.0502 - val_accuracy: 0.5833 - val_loss: 1.0242
# Epoch 9/200
#
# Epoch 9: val_loss improved from 1.02419 to 1.01471, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.6042 - loss: 1.0411 - val_accuracy: 0.7083 - val_loss: 1.0147
# Epoch 10/200
#
# Epoch 10: val_loss improved from 1.01471 to 1.00496, saving model to best_model_iris.keras
# 3/3 - 0s - 52ms/step - accuracy: 0.6458 - loss: 1.0320 - val_accuracy: 0.7083 - val_loss: 1.0050
# Epoch 11/200
#
# Epoch 11: val_loss improved from 1.00496 to 0.99489, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.6562 - loss: 1.0226 - val_accuracy: 0.7500 - val_loss: 0.9949
# Epoch 12/200
#
# Epoch 12: val_loss improved from 0.99489 to 0.98452, saving model to best_model_iris.keras
# 3/3 - 0s - 57ms/step - accuracy: 0.6771 - loss: 1.0131 - val_accuracy: 0.7500 - val_loss: 0.9845
# Epoch 13/200
#
# Epoch 13: val_loss improved from 0.98452 to 0.97399, saving model to best_model_iris.keras
# 3/3 - 0s - 67ms/step - accuracy: 0.6875 - loss: 1.0038 - val_accuracy: 0.7500 - val_loss: 0.9740
# Epoch 14/200
#
# Epoch 14: val_loss improved from 0.97399 to 0.96372, saving model to best_model_iris.keras
# 3/3 - 0s - 52ms/step - accuracy: 0.7083 - loss: 0.9940 - val_accuracy: 0.7500 - val_loss: 0.9637
# Epoch 15/200
#
# Epoch 15: val_loss improved from 0.96372 to 0.95316, saving model to best_model_iris.keras
# 3/3 - 0s - 63ms/step - accuracy: 0.7188 - loss: 0.9845 - val_accuracy: 0.7917 - val_loss: 0.9532
# Epoch 16/200
#
# Epoch 16: val_loss improved from 0.95316 to 0.94215, saving model to best_model_iris.keras
# 3/3 - 0s - 65ms/step - accuracy: 0.7292 - loss: 0.9750 - val_accuracy: 0.7917 - val_loss: 0.9422
# Epoch 17/200
#
# Epoch 17: val_loss improved from 0.94215 to 0.93122, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.7396 - loss: 0.9650 - val_accuracy: 0.7917 - val_loss: 0.9312
# Epoch 18/200
#
# Epoch 18: val_loss improved from 0.93122 to 0.92027, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.7500 - loss: 0.9551 - val_accuracy: 0.7917 - val_loss: 0.9203
# Epoch 19/200
#
# Epoch 19: val_loss improved from 0.92027 to 0.90878, saving model to best_model_iris.keras
# 3/3 - 0s - 60ms/step - accuracy: 0.7604 - loss: 0.9452 - val_accuracy: 0.8333 - val_loss: 0.9088
# Epoch 20/200
#
# Epoch 20: val_loss improved from 0.90878 to 0.89729, saving model to best_model_iris.keras
# 3/3 - 0s - 73ms/step - accuracy: 0.7708 - loss: 0.9350 - val_accuracy: 0.8333 - val_loss: 0.8973
# Epoch 21/200
#
# Epoch 21: val_loss improved from 0.89729 to 0.88508, saving model to best_model_iris.keras
# 3/3 - 0s - 57ms/step - accuracy: 0.7917 - loss: 0.9252 - val_accuracy: 0.8333 - val_loss: 0.8851
# Epoch 22/200
#
# Epoch 22: val_loss improved from 0.88508 to 0.87303, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.7917 - loss: 0.9147 - val_accuracy: 0.8333 - val_loss: 0.8730
# Epoch 23/200
#
# Epoch 23: val_loss improved from 0.87303 to 0.86092, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.8021 - loss: 0.9040 - val_accuracy: 0.7917 - val_loss: 0.8609
# Epoch 24/200
#
# Epoch 24: val_loss improved from 0.86092 to 0.84838, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.8021 - loss: 0.8936 - val_accuracy: 0.7917 - val_loss: 0.8484
# Epoch 25/200
#
# Epoch 25: val_loss improved from 0.84838 to 0.83590, saving model to best_model_iris.keras
# 3/3 - 0s - 55ms/step - accuracy: 0.8125 - loss: 0.8828 - val_accuracy: 0.7917 - val_loss: 0.8359
# Epoch 26/200
#
# Epoch 26: val_loss improved from 0.83590 to 0.82327, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8125 - loss: 0.8722 - val_accuracy: 0.7917 - val_loss: 0.8233
# Epoch 27/200
#
# Epoch 27: val_loss improved from 0.82327 to 0.81031, saving model to best_model_iris.keras
# 3/3 - 0s - 55ms/step - accuracy: 0.8125 - loss: 0.8608 - val_accuracy: 0.8333 - val_loss: 0.8103
# Epoch 28/200
#
# Epoch 28: val_loss improved from 0.81031 to 0.79733, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.8021 - loss: 0.8495 - val_accuracy: 0.8333 - val_loss: 0.7973
# Epoch 29/200
#
# Epoch 29: val_loss improved from 0.79733 to 0.78392, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8021 - loss: 0.8381 - val_accuracy: 0.8333 - val_loss: 0.7839
# Epoch 30/200
#
# Epoch 30: val_loss improved from 0.78392 to 0.77046, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.8021 - loss: 0.8265 - val_accuracy: 0.8333 - val_loss: 0.7705
# Epoch 31/200
#
# Epoch 31: val_loss improved from 0.77046 to 0.75727, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.8021 - loss: 0.8145 - val_accuracy: 0.8333 - val_loss: 0.7573
# Epoch 32/200
#
# Epoch 32: val_loss improved from 0.75727 to 0.74345, saving model to best_model_iris.keras
# 3/3 - 0s - 69ms/step - accuracy: 0.8021 - loss: 0.8025 - val_accuracy: 0.8333 - val_loss: 0.7434
# Epoch 33/200
#
# Epoch 33: val_loss improved from 0.74345 to 0.72944, saving model to best_model_iris.keras
# 3/3 - 0s - 50ms/step - accuracy: 0.8021 - loss: 0.7909 - val_accuracy: 0.8333 - val_loss: 0.7294
# Epoch 34/200
#
# Epoch 34: val_loss improved from 0.72944 to 0.71618, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8021 - loss: 0.7785 - val_accuracy: 0.8333 - val_loss: 0.7162
# Epoch 35/200
#
# Epoch 35: val_loss improved from 0.71618 to 0.70364, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.8021 - loss: 0.7665 - val_accuracy: 0.8333 - val_loss: 0.7036
# Epoch 36/200
#
# Epoch 36: val_loss improved from 0.70364 to 0.69083, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8021 - loss: 0.7548 - val_accuracy: 0.8333 - val_loss: 0.6908
# Epoch 37/200
#
# Epoch 37: val_loss improved from 0.69083 to 0.67900, saving model to best_model_iris.keras
# 3/3 - 0s - 60ms/step - accuracy: 0.8021 - loss: 0.7429 - val_accuracy: 0.8333 - val_loss: 0.6790
# Epoch 38/200
#
# Epoch 38: val_loss improved from 0.67900 to 0.66712, saving model to best_model_iris.keras
# 3/3 - 0s - 54ms/step - accuracy: 0.8021 - loss: 0.7311 - val_accuracy: 0.8333 - val_loss: 0.6671
# Epoch 39/200
#
# Epoch 39: val_loss improved from 0.66712 to 0.65526, saving model to best_model_iris.keras
# 3/3 - 0s - 58ms/step - accuracy: 0.8021 - loss: 0.7197 - val_accuracy: 0.8333 - val_loss: 0.6553
# Epoch 40/200
#
# Epoch 40: val_loss improved from 0.65526 to 0.64357, saving model to best_model_iris.keras
# 3/3 - 0s - 57ms/step - accuracy: 0.8021 - loss: 0.7080 - val_accuracy: 0.8333 - val_loss: 0.6436
# Epoch 41/200
#
# Epoch 41: val_loss improved from 0.64357 to 0.63239, saving model to best_model_iris.keras
# 3/3 - 0s - 63ms/step - accuracy: 0.8021 - loss: 0.6964 - val_accuracy: 0.8333 - val_loss: 0.6324
# Epoch 42/200
#
# Epoch 42: val_loss improved from 0.63239 to 0.62170, saving model to best_model_iris.keras
# 3/3 - 0s - 68ms/step - accuracy: 0.8021 - loss: 0.6850 - val_accuracy: 0.8333 - val_loss: 0.6217
# Epoch 43/200
#
# Epoch 43: val_loss improved from 0.62170 to 0.61151, saving model to best_model_iris.keras
# 3/3 - 0s - 59ms/step - accuracy: 0.8021 - loss: 0.6735 - val_accuracy: 0.8333 - val_loss: 0.6115
# Epoch 44/200
#
# Epoch 44: val_loss improved from 0.61151 to 0.60132, saving model to best_model_iris.keras
# 3/3 - 0s - 62ms/step - accuracy: 0.8125 - loss: 0.6622 - val_accuracy: 0.8333 - val_loss: 0.6013
# Epoch 45/200
#
# Epoch 45: val_loss improved from 0.60132 to 0.59165, saving model to best_model_iris.keras
# 3/3 - 0s - 51ms/step - accuracy: 0.8125 - loss: 0.6509 - val_accuracy: 0.8333 - val_loss: 0.5917
# Epoch 46/200
#
# Epoch 46: val_loss improved from 0.59165 to 0.58228, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8021 - loss: 0.6398 - val_accuracy: 0.8333 - val_loss: 0.5823
# Epoch 47/200
#
# Epoch 47: val_loss improved from 0.58228 to 0.57259, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8125 - loss: 0.6292 - val_accuracy: 0.8750 - val_loss: 0.5726
# Epoch 48/200
#
# Epoch 48: val_loss improved from 0.57259 to 0.56367, saving model to best_model_iris.keras
# 3/3 - 0s - 52ms/step - accuracy: 0.8125 - loss: 0.6181 - val_accuracy: 0.8750 - val_loss: 0.5637
# Epoch 49/200
#
# Epoch 49: val_loss improved from 0.56367 to 0.55541, saving model to best_model_iris.keras
# 3/3 - 0s - 58ms/step - accuracy: 0.8125 - loss: 0.6077 - val_accuracy: 0.8750 - val_loss: 0.5554
# Epoch 50/200
#
# Epoch 50: val_loss improved from 0.55541 to 0.54673, saving model to best_model_iris.keras
# 3/3 - 0s - 58ms/step - accuracy: 0.8229 - loss: 0.5971 - val_accuracy: 0.8750 - val_loss: 0.5467
# Epoch 51/200
#
# Epoch 51: val_loss improved from 0.54673 to 0.53868, saving model to best_model_iris.keras
# 3/3 - 0s - 47ms/step - accuracy: 0.8229 - loss: 0.5866 - val_accuracy: 0.8750 - val_loss: 0.5387
# Epoch 52/200
#
# Epoch 52: val_loss improved from 0.53868 to 0.53036, saving model to best_model_iris.keras
# 3/3 - 0s - 50ms/step - accuracy: 0.8229 - loss: 0.5765 - val_accuracy: 0.8750 - val_loss: 0.5304
# Epoch 53/200
#
# Epoch 53: val_loss improved from 0.53036 to 0.52275, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8229 - loss: 0.5663 - val_accuracy: 0.8750 - val_loss: 0.5227
# Epoch 54/200
#
# Epoch 54: val_loss improved from 0.52275 to 0.51505, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8229 - loss: 0.5563 - val_accuracy: 0.9167 - val_loss: 0.5151
# Epoch 55/200
#
# Epoch 55: val_loss improved from 0.51505 to 0.50792, saving model to best_model_iris.keras
# 3/3 - 0s - 46ms/step - accuracy: 0.8229 - loss: 0.5466 - val_accuracy: 0.9167 - val_loss: 0.5079
# Epoch 56/200
#
# Epoch 56: val_loss improved from 0.50792 to 0.50068, saving model to best_model_iris.keras
# 3/3 - 0s - 45ms/step - accuracy: 0.8229 - loss: 0.5371 - val_accuracy: 0.9167 - val_loss: 0.5007
# Epoch 57/200
#
# Epoch 57: val_loss improved from 0.50068 to 0.49324, saving model to best_model_iris.keras
# 3/3 - 0s - 53ms/step - accuracy: 0.8229 - loss: 0.5279 - val_accuracy: 0.9167 - val_loss: 0.4932
# Epoch 58/200
#
# Epoch 58: val_loss improved from 0.49324 to 0.48690, saving model to best_model_iris.keras
# 3/3 - 0s - 108ms/step - accuracy: 0.8229 - loss: 0.5185 - val_accuracy: 0.9167 - val_loss: 0.4869
# Epoch 59/200
#
# Epoch 59: val_loss improved from 0.48690 to 0.48026, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.8229 - loss: 0.5093 - val_accuracy: 0.9167 - val_loss: 0.4803
# Epoch 60/200
#
# Epoch 60: val_loss improved from 0.48026 to 0.47340, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.8229 - loss: 0.5007 - val_accuracy: 0.9167 - val_loss: 0.4734
# Epoch 61/200
#
# Epoch 61: val_loss improved from 0.47340 to 0.46737, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.8229 - loss: 0.4919 - val_accuracy: 0.9167 - val_loss: 0.4674
# Epoch 62/200
#
# Epoch 62: val_loss improved from 0.46737 to 0.46149, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.8229 - loss: 0.4836 - val_accuracy: 0.9167 - val_loss: 0.4615
# Epoch 63/200
#
# Epoch 63: val_loss improved from 0.46149 to 0.45550, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.8333 - loss: 0.4753 - val_accuracy: 0.9167 - val_loss: 0.4555
# Epoch 64/200
#
# Epoch 64: val_loss improved from 0.45550 to 0.44803, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.8438 - loss: 0.4667 - val_accuracy: 0.9167 - val_loss: 0.4480
# Epoch 65/200
#
# Epoch 65: val_loss improved from 0.44803 to 0.44049, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.8438 - loss: 0.4566 - val_accuracy: 0.9167 - val_loss: 0.4405
# Epoch 66/200
#
# Epoch 66: val_loss improved from 0.44049 to 0.43279, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.8438 - loss: 0.4454 - val_accuracy: 0.9167 - val_loss: 0.4328
# Epoch 67/200
#
# Epoch 67: val_loss improved from 0.43279 to 0.42468, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.8542 - loss: 0.4332 - val_accuracy: 0.9167 - val_loss: 0.4247
# Epoch 68/200
#
# Epoch 68: val_loss improved from 0.42468 to 0.41723, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.8542 - loss: 0.4211 - val_accuracy: 0.9167 - val_loss: 0.4172
# Epoch 69/200
#
# Epoch 69: val_loss improved from 0.41723 to 0.40902, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.8542 - loss: 0.4096 - val_accuracy: 0.9167 - val_loss: 0.4090
# Epoch 70/200
#
# Epoch 70: val_loss improved from 0.40902 to 0.40169, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.8646 - loss: 0.3992 - val_accuracy: 0.9167 - val_loss: 0.4017
# Epoch 71/200
#
# Epoch 71: val_loss improved from 0.40169 to 0.39519, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.8646 - loss: 0.3888 - val_accuracy: 0.9167 - val_loss: 0.3952
# Epoch 72/200
#
# Epoch 72: val_loss improved from 0.39519 to 0.38891, saving model to best_model_iris.keras
# 3/3 - 0s - 64ms/step - accuracy: 0.8750 - loss: 0.3800 - val_accuracy: 0.9167 - val_loss: 0.3889
# Epoch 73/200
#
# Epoch 73: val_loss improved from 0.38891 to 0.38332, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.8750 - loss: 0.3713 - val_accuracy: 0.9167 - val_loss: 0.3833
# Epoch 74/200
#
# Epoch 74: val_loss improved from 0.38332 to 0.37831, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.8854 - loss: 0.3638 - val_accuracy: 0.9167 - val_loss: 0.3783
# Epoch 75/200
#
# Epoch 75: val_loss improved from 0.37831 to 0.37411, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.8958 - loss: 0.3567 - val_accuracy: 0.9167 - val_loss: 0.3741
# Epoch 76/200
#
# Epoch 76: val_loss improved from 0.37411 to 0.37030, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9062 - loss: 0.3503 - val_accuracy: 0.9167 - val_loss: 0.3703
# Epoch 77/200
#
# Epoch 77: val_loss improved from 0.37030 to 0.36658, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9167 - loss: 0.3446 - val_accuracy: 0.9167 - val_loss: 0.3666
# Epoch 78/200
#
# Epoch 78: val_loss improved from 0.36658 to 0.36222, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9271 - loss: 0.3390 - val_accuracy: 0.9167 - val_loss: 0.3622
# Epoch 79/200
#
# Epoch 79: val_loss improved from 0.36222 to 0.35818, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9271 - loss: 0.3339 - val_accuracy: 0.9167 - val_loss: 0.3582
# Epoch 80/200
#
# Epoch 80: val_loss improved from 0.35818 to 0.35439, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9271 - loss: 0.3290 - val_accuracy: 0.9167 - val_loss: 0.3544
# Epoch 81/200
#
# Epoch 81: val_loss improved from 0.35439 to 0.35065, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9271 - loss: 0.3245 - val_accuracy: 0.9167 - val_loss: 0.3507
# Epoch 82/200
#
# Epoch 82: val_loss improved from 0.35065 to 0.34768, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9271 - loss: 0.3203 - val_accuracy: 0.9167 - val_loss: 0.3477
# Epoch 83/200
#
# Epoch 83: val_loss improved from 0.34768 to 0.34441, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9271 - loss: 0.3161 - val_accuracy: 0.9167 - val_loss: 0.3444
# Epoch 84/200
#
# Epoch 84: val_loss improved from 0.34441 to 0.34198, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9271 - loss: 0.3122 - val_accuracy: 0.9167 - val_loss: 0.3420
# Epoch 85/200
#
# Epoch 85: val_loss improved from 0.34198 to 0.33889, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9271 - loss: 0.3083 - val_accuracy: 0.9167 - val_loss: 0.3389
# Epoch 86/200
#
# Epoch 86: val_loss improved from 0.33889 to 0.33604, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9271 - loss: 0.3047 - val_accuracy: 0.9167 - val_loss: 0.3360
# Epoch 87/200
#
# Epoch 87: val_loss improved from 0.33604 to 0.33287, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.9271 - loss: 0.3014 - val_accuracy: 0.9167 - val_loss: 0.3329
# Epoch 88/200
#
# Epoch 88: val_loss improved from 0.33287 to 0.33012, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9271 - loss: 0.2977 - val_accuracy: 0.9167 - val_loss: 0.3301
# Epoch 89/200
#
# Epoch 89: val_loss improved from 0.33012 to 0.32778, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9271 - loss: 0.2946 - val_accuracy: 0.9167 - val_loss: 0.3278
# Epoch 90/200
#
# Epoch 90: val_loss improved from 0.32778 to 0.32588, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9271 - loss: 0.2914 - val_accuracy: 0.9167 - val_loss: 0.3259
# Epoch 91/200
#
# Epoch 91: val_loss improved from 0.32588 to 0.32314, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9271 - loss: 0.2880 - val_accuracy: 0.9167 - val_loss: 0.3231
# Epoch 92/200
#
# Epoch 92: val_loss improved from 0.32314 to 0.32036, saving model to best_model_iris.keras
# 3/3 - 0s - 37ms/step - accuracy: 0.9271 - loss: 0.2850 - val_accuracy: 0.9167 - val_loss: 0.3204
# Epoch 93/200
#
# Epoch 93: val_loss improved from 0.32036 to 0.31772, saving model to best_model_iris.keras
# 3/3 - 0s - 37ms/step - accuracy: 0.9271 - loss: 0.2820 - val_accuracy: 0.9167 - val_loss: 0.3177
# Epoch 94/200
#
# Epoch 94: val_loss improved from 0.31772 to 0.31461, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9375 - loss: 0.2790 - val_accuracy: 0.9167 - val_loss: 0.3146
# Epoch 95/200
#
# Epoch 95: val_loss improved from 0.31461 to 0.31227, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9375 - loss: 0.2762 - val_accuracy: 0.9167 - val_loss: 0.3123
# Epoch 96/200
#
# Epoch 96: val_loss improved from 0.31227 to 0.31028, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9375 - loss: 0.2734 - val_accuracy: 0.9167 - val_loss: 0.3103
# Epoch 97/200
#
# Epoch 97: val_loss improved from 0.31028 to 0.30801, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9375 - loss: 0.2705 - val_accuracy: 0.9167 - val_loss: 0.3080
# Epoch 98/200
#
# Epoch 98: val_loss improved from 0.30801 to 0.30533, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9375 - loss: 0.2678 - val_accuracy: 0.9583 - val_loss: 0.3053
# Epoch 99/200
#
# Epoch 99: val_loss improved from 0.30533 to 0.30306, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9375 - loss: 0.2651 - val_accuracy: 0.9583 - val_loss: 0.3031
# Epoch 100/200
#
# Epoch 100: val_loss improved from 0.30306 to 0.30131, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9375 - loss: 0.2625 - val_accuracy: 0.9583 - val_loss: 0.3013
# Epoch 101/200
#
# Epoch 101: val_loss improved from 0.30131 to 0.29927, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.2598 - val_accuracy: 0.9583 - val_loss: 0.2993
# Epoch 102/200
#
# Epoch 102: val_loss improved from 0.29927 to 0.29732, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2571 - val_accuracy: 0.9583 - val_loss: 0.2973
# Epoch 103/200
#
# Epoch 103: val_loss improved from 0.29732 to 0.29492, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2545 - val_accuracy: 0.9583 - val_loss: 0.2949
# Epoch 104/200
#
# Epoch 104: val_loss improved from 0.29492 to 0.29380, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2521 - val_accuracy: 0.9583 - val_loss: 0.2938
# Epoch 105/200
#
# Epoch 105: val_loss improved from 0.29380 to 0.29175, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2495 - val_accuracy: 0.9583 - val_loss: 0.2918
# Epoch 106/200
#
# Epoch 106: val_loss improved from 0.29175 to 0.28936, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2470 - val_accuracy: 0.9583 - val_loss: 0.2894
# Epoch 107/200
#
# Epoch 107: val_loss improved from 0.28936 to 0.28748, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.9479 - loss: 0.2446 - val_accuracy: 0.9583 - val_loss: 0.2875
# Epoch 108/200
#
# Epoch 108: val_loss improved from 0.28748 to 0.28548, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2421 - val_accuracy: 0.9583 - val_loss: 0.2855
# Epoch 109/200
#
# Epoch 109: val_loss improved from 0.28548 to 0.28310, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2396 - val_accuracy: 0.9583 - val_loss: 0.2831
# Epoch 110/200
#
# Epoch 110: val_loss improved from 0.28310 to 0.28057, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2374 - val_accuracy: 0.9583 - val_loss: 0.2806
# Epoch 111/200
#
# Epoch 111: val_loss improved from 0.28057 to 0.27817, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2350 - val_accuracy: 0.9583 - val_loss: 0.2782
# Epoch 112/200
#
# Epoch 112: val_loss improved from 0.27817 to 0.27602, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2325 - val_accuracy: 0.9583 - val_loss: 0.2760
# Epoch 113/200
#
# Epoch 113: val_loss improved from 0.27602 to 0.27425, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2304 - val_accuracy: 0.9583 - val_loss: 0.2743
# Epoch 114/200
#
# Epoch 114: val_loss improved from 0.27425 to 0.27285, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2280 - val_accuracy: 0.9583 - val_loss: 0.2729
# Epoch 115/200
#
# Epoch 115: val_loss improved from 0.27285 to 0.27099, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2258 - val_accuracy: 0.9583 - val_loss: 0.2710
# Epoch 116/200
#
# Epoch 116: val_loss improved from 0.27099 to 0.26942, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2235 - val_accuracy: 0.9583 - val_loss: 0.2694
# Epoch 117/200
#
# Epoch 117: val_loss improved from 0.26942 to 0.26806, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2216 - val_accuracy: 0.9583 - val_loss: 0.2681
# Epoch 118/200
#
# Epoch 118: val_loss improved from 0.26806 to 0.26524, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2193 - val_accuracy: 0.9583 - val_loss: 0.2652
# Epoch 119/200
#
# Epoch 119: val_loss improved from 0.26524 to 0.26310, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2172 - val_accuracy: 0.9583 - val_loss: 0.2631
# Epoch 120/200
#
# Epoch 120: val_loss improved from 0.26310 to 0.26232, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2151 - val_accuracy: 0.9583 - val_loss: 0.2623
# Epoch 121/200
#
# Epoch 121: val_loss improved from 0.26232 to 0.26080, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2129 - val_accuracy: 0.9583 - val_loss: 0.2608
# Epoch 122/200
#
# Epoch 122: val_loss improved from 0.26080 to 0.25896, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2107 - val_accuracy: 0.9583 - val_loss: 0.2590
# Epoch 123/200
#
# Epoch 123: val_loss improved from 0.25896 to 0.25780, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.9479 - loss: 0.2088 - val_accuracy: 0.9583 - val_loss: 0.2578
# Epoch 124/200
#
# Epoch 124: val_loss improved from 0.25780 to 0.25611, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2066 - val_accuracy: 0.9583 - val_loss: 0.2561
# Epoch 125/200
#
# Epoch 125: val_loss improved from 0.25611 to 0.25345, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2047 - val_accuracy: 0.9583 - val_loss: 0.2535
# Epoch 126/200
#
# Epoch 126: val_loss improved from 0.25345 to 0.25234, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.2027 - val_accuracy: 0.9583 - val_loss: 0.2523
# Epoch 127/200
#
# Epoch 127: val_loss improved from 0.25234 to 0.25010, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.2008 - val_accuracy: 0.9583 - val_loss: 0.2501
# Epoch 128/200
#
# Epoch 128: val_loss improved from 0.25010 to 0.24813, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1988 - val_accuracy: 0.9583 - val_loss: 0.2481
# Epoch 129/200
#
# Epoch 129: val_loss improved from 0.24813 to 0.24761, saving model to best_model_iris.keras
# 3/3 - 0s - 44ms/step - accuracy: 0.9479 - loss: 0.1971 - val_accuracy: 0.9583 - val_loss: 0.2476
# Epoch 130/200
#
# Epoch 130: val_loss improved from 0.24761 to 0.24644, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1949 - val_accuracy: 0.9583 - val_loss: 0.2464
# Epoch 131/200
#
# Epoch 131: val_loss improved from 0.24644 to 0.24505, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1930 - val_accuracy: 0.9583 - val_loss: 0.2450
# Epoch 132/200
#
# Epoch 132: val_loss improved from 0.24505 to 0.24384, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1911 - val_accuracy: 0.9583 - val_loss: 0.2438
# Epoch 133/200
#
# Epoch 133: val_loss improved from 0.24384 to 0.24315, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1893 - val_accuracy: 0.9583 - val_loss: 0.2431
# Epoch 134/200
#
# Epoch 134: val_loss improved from 0.24315 to 0.24182, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1873 - val_accuracy: 0.9583 - val_loss: 0.2418
# Epoch 135/200
#
# Epoch 135: val_loss improved from 0.24182 to 0.24101, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1858 - val_accuracy: 0.9583 - val_loss: 0.2410
# Epoch 136/200
#
# Epoch 136: val_loss improved from 0.24101 to 0.23912, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1837 - val_accuracy: 0.9583 - val_loss: 0.2391
# Epoch 137/200
#
# Epoch 137: val_loss improved from 0.23912 to 0.23830, saving model to best_model_iris.keras
# 3/3 - 0s - 41ms/step - accuracy: 0.9479 - loss: 0.1822 - val_accuracy: 0.9583 - val_loss: 0.2383
# Epoch 138/200
#
# Epoch 138: val_loss improved from 0.23830 to 0.23609, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1804 - val_accuracy: 0.9583 - val_loss: 0.2361
# Epoch 139/200
#
# Epoch 139: val_loss improved from 0.23609 to 0.23418, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1786 - val_accuracy: 0.9583 - val_loss: 0.2342
# Epoch 140/200
#
# Epoch 140: val_loss improved from 0.23418 to 0.23279, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1769 - val_accuracy: 0.9583 - val_loss: 0.2328
# Epoch 141/200
#
# Epoch 141: val_loss improved from 0.23279 to 0.23074, saving model to best_model_iris.keras
# 3/3 - 0s - 63ms/step - accuracy: 0.9479 - loss: 0.1753 - val_accuracy: 0.9583 - val_loss: 0.2307
# Epoch 142/200
#
# Epoch 142: val_loss improved from 0.23074 to 0.23013, saving model to best_model_iris.keras
# 3/3 - 0s - 37ms/step - accuracy: 0.9479 - loss: 0.1738 - val_accuracy: 0.9583 - val_loss: 0.2301
# Epoch 143/200
#
# Epoch 143: val_loss improved from 0.23013 to 0.22875, saving model to best_model_iris.keras
# 3/3 - 0s - 37ms/step - accuracy: 0.9479 - loss: 0.1720 - val_accuracy: 0.9583 - val_loss: 0.2287
# Epoch 144/200
#
# Epoch 144: val_loss improved from 0.22875 to 0.22654, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1705 - val_accuracy: 0.9583 - val_loss: 0.2265
# Epoch 145/200
#
# Epoch 145: val_loss improved from 0.22654 to 0.22576, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1691 - val_accuracy: 0.9583 - val_loss: 0.2258
# Epoch 146/200
#
# Epoch 146: val_loss improved from 0.22576 to 0.22409, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1674 - val_accuracy: 0.9583 - val_loss: 0.2241
# Epoch 147/200
#
# Epoch 147: val_loss improved from 0.22409 to 0.22309, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1659 - val_accuracy: 0.9583 - val_loss: 0.2231
# Epoch 148/200
#
# Epoch 148: val_loss improved from 0.22309 to 0.22156, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1645 - val_accuracy: 0.9583 - val_loss: 0.2216
# Epoch 149/200
#
# Epoch 149: val_loss improved from 0.22156 to 0.22067, saving model to best_model_iris.keras
# 3/3 - 0s - 44ms/step - accuracy: 0.9479 - loss: 0.1629 - val_accuracy: 0.9583 - val_loss: 0.2207
# Epoch 150/200
#
# Epoch 150: val_loss improved from 0.22067 to 0.21886, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1616 - val_accuracy: 0.9583 - val_loss: 0.2189
# Epoch 151/200
#
# Epoch 151: val_loss improved from 0.21886 to 0.21729, saving model to best_model_iris.keras
# 3/3 - 0s - 42ms/step - accuracy: 0.9479 - loss: 0.1600 - val_accuracy: 0.9583 - val_loss: 0.2173
# Epoch 152/200
#
# Epoch 152: val_loss improved from 0.21729 to 0.21656, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1586 - val_accuracy: 0.9583 - val_loss: 0.2166
# Epoch 153/200
#
# Epoch 153: val_loss improved from 0.21656 to 0.21565, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1571 - val_accuracy: 0.9583 - val_loss: 0.2157
# Epoch 154/200
#
# Epoch 154: val_loss improved from 0.21565 to 0.21417, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1557 - val_accuracy: 0.9583 - val_loss: 0.2142
# Epoch 155/200
#
# Epoch 155: val_loss improved from 0.21417 to 0.21325, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1544 - val_accuracy: 0.9583 - val_loss: 0.2132
# Epoch 156/200
#
# Epoch 156: val_loss improved from 0.21325 to 0.21315, saving model to best_model_iris.keras
# 3/3 - 0s - 37ms/step - accuracy: 0.9479 - loss: 0.1530 - val_accuracy: 0.9583 - val_loss: 0.2132
# Epoch 157/200
#
# Epoch 157: val_loss improved from 0.21315 to 0.21241, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1515 - val_accuracy: 0.9583 - val_loss: 0.2124
# Epoch 158/200
#
# Epoch 158: val_loss improved from 0.21241 to 0.21116, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1503 - val_accuracy: 0.9583 - val_loss: 0.2112
# Epoch 159/200
#
# Epoch 159: val_loss improved from 0.21116 to 0.20995, saving model to best_model_iris.keras
# 3/3 - 0s - 50ms/step - accuracy: 0.9479 - loss: 0.1488 - val_accuracy: 0.9583 - val_loss: 0.2099
# Epoch 160/200
#
# Epoch 160: val_loss improved from 0.20995 to 0.20812, saving model to best_model_iris.keras
# 3/3 - 0s - 56ms/step - accuracy: 0.9479 - loss: 0.1474 - val_accuracy: 0.9583 - val_loss: 0.2081
# Epoch 161/200
#
# Epoch 161: val_loss improved from 0.20812 to 0.20653, saving model to best_model_iris.keras
# 3/3 - 0s - 42ms/step - accuracy: 0.9479 - loss: 0.1461 - val_accuracy: 0.9583 - val_loss: 0.2065
# Epoch 162/200
#
# Epoch 162: val_loss improved from 0.20653 to 0.20450, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1449 - val_accuracy: 0.9583 - val_loss: 0.2045
# Epoch 163/200
#
# Epoch 163: val_loss improved from 0.20450 to 0.20381, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1435 - val_accuracy: 0.9583 - val_loss: 0.2038
# Epoch 164/200
#
# Epoch 164: val_loss did not improve from 0.20381
# 3/3 - 0s - 45ms/step - accuracy: 0.9479 - loss: 0.1425 - val_accuracy: 0.9583 - val_loss: 0.2043
# Epoch 165/200
#
# Epoch 165: val_loss improved from 0.20381 to 0.20270, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1409 - val_accuracy: 0.9583 - val_loss: 0.2027
# Epoch 166/200
#
# Epoch 166: val_loss improved from 0.20270 to 0.20058, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1398 - val_accuracy: 0.9583 - val_loss: 0.2006
# Epoch 167/200
#
# Epoch 167: val_loss improved from 0.20058 to 0.19901, saving model to best_model_iris.keras
# 3/3 - 0s - 44ms/step - accuracy: 0.9479 - loss: 0.1384 - val_accuracy: 0.9583 - val_loss: 0.1990
# Epoch 168/200
#
# Epoch 168: val_loss improved from 0.19901 to 0.19830, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1372 - val_accuracy: 0.9583 - val_loss: 0.1983
# Epoch 169/200
#
# Epoch 169: val_loss improved from 0.19830 to 0.19801, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1359 - val_accuracy: 0.9583 - val_loss: 0.1980
# Epoch 170/200
#
# Epoch 170: val_loss improved from 0.19801 to 0.19681, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1348 - val_accuracy: 0.9583 - val_loss: 0.1968
# Epoch 171/200
#
# Epoch 171: val_loss improved from 0.19681 to 0.19468, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1339 - val_accuracy: 0.9583 - val_loss: 0.1947
# Epoch 172/200
#
# Epoch 172: val_loss improved from 0.19468 to 0.19382, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1325 - val_accuracy: 0.9583 - val_loss: 0.1938
# Epoch 173/200
#
# Epoch 173: val_loss improved from 0.19382 to 0.19251, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1315 - val_accuracy: 0.9583 - val_loss: 0.1925
# Epoch 174/200
#
# Epoch 174: val_loss improved from 0.19251 to 0.19178, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1304 - val_accuracy: 0.9583 - val_loss: 0.1918
# Epoch 175/200
#
# Epoch 175: val_loss did not improve from 0.19178
# 3/3 - 0s - 31ms/step - accuracy: 0.9479 - loss: 0.1299 - val_accuracy: 0.9583 - val_loss: 0.1929
# Epoch 176/200
#
# Epoch 176: val_loss improved from 0.19178 to 0.19113, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1286 - val_accuracy: 0.9583 - val_loss: 0.1911
# Epoch 177/200
#
# Epoch 177: val_loss improved from 0.19113 to 0.19036, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1275 - val_accuracy: 0.9583 - val_loss: 0.1904
# Epoch 178/200
#
# Epoch 178: val_loss improved from 0.19036 to 0.19029, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1267 - val_accuracy: 0.9583 - val_loss: 0.1903
# Epoch 179/200
#
# Epoch 179: val_loss improved from 0.19029 to 0.18923, saving model to best_model_iris.keras
# 3/3 - 0s - 42ms/step - accuracy: 0.9479 - loss: 0.1257 - val_accuracy: 0.9583 - val_loss: 0.1892
# Epoch 180/200
#
# Epoch 180: val_loss improved from 0.18923 to 0.18754, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1248 - val_accuracy: 0.9583 - val_loss: 0.1875
# Epoch 181/200
#
# Epoch 181: val_loss improved from 0.18754 to 0.18653, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1238 - val_accuracy: 0.9583 - val_loss: 0.1865
# Epoch 182/200
#
# Epoch 182: val_loss improved from 0.18653 to 0.18641, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1231 - val_accuracy: 0.9583 - val_loss: 0.1864
# Epoch 183/200
#
# Epoch 183: val_loss improved from 0.18641 to 0.18538, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1222 - val_accuracy: 0.9583 - val_loss: 0.1854
# Epoch 184/200
#
# Epoch 184: val_loss improved from 0.18538 to 0.18427, saving model to best_model_iris.keras
# 3/3 - 0s - 40ms/step - accuracy: 0.9479 - loss: 0.1213 - val_accuracy: 0.9583 - val_loss: 0.1843
# Epoch 185/200
#
# Epoch 185: val_loss improved from 0.18427 to 0.18315, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1205 - val_accuracy: 0.9583 - val_loss: 0.1832
# Epoch 186/200
#
# Epoch 186: val_loss improved from 0.18315 to 0.18247, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1196 - val_accuracy: 0.9583 - val_loss: 0.1825
# Epoch 187/200
#
# Epoch 187: val_loss improved from 0.18247 to 0.18101, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1189 - val_accuracy: 0.9583 - val_loss: 0.1810
# Epoch 188/200
#
# Epoch 188: val_loss improved from 0.18101 to 0.18089, saving model to best_model_iris.keras
# 3/3 - 0s - 37ms/step - accuracy: 0.9479 - loss: 0.1180 - val_accuracy: 0.9583 - val_loss: 0.1809
# Epoch 189/200
#
# Epoch 189: val_loss improved from 0.18089 to 0.17940, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1174 - val_accuracy: 0.9583 - val_loss: 0.1794
# Epoch 190/200
#
# Epoch 190: val_loss improved from 0.17940 to 0.17894, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9479 - loss: 0.1165 - val_accuracy: 0.9583 - val_loss: 0.1789
# Epoch 191/200
#
# Epoch 191: val_loss improved from 0.17894 to 0.17786, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9479 - loss: 0.1158 - val_accuracy: 0.9583 - val_loss: 0.1779
# Epoch 192/200
#
# Epoch 192: val_loss did not improve from 0.17786
# 3/3 - 0s - 30ms/step - accuracy: 0.9479 - loss: 0.1150 - val_accuracy: 0.9583 - val_loss: 0.1782
# Epoch 193/200
#
# Epoch 193: val_loss improved from 0.17786 to 0.17762, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9583 - loss: 0.1143 - val_accuracy: 0.9583 - val_loss: 0.1776
# Epoch 194/200
#
# Epoch 194: val_loss improved from 0.17762 to 0.17692, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9583 - loss: 0.1136 - val_accuracy: 0.9583 - val_loss: 0.1769
# Epoch 195/200
#
# Epoch 195: val_loss improved from 0.17692 to 0.17561, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9583 - loss: 0.1129 - val_accuracy: 0.9583 - val_loss: 0.1756
# Epoch 196/200
#
# Epoch 196: val_loss did not improve from 0.17561
# 3/3 - 0s - 29ms/step - accuracy: 0.9583 - loss: 0.1124 - val_accuracy: 0.9583 - val_loss: 0.1769
# Epoch 197/200
#
# Epoch 197: val_loss improved from 0.17561 to 0.17522, saving model to best_model_iris.keras
# 3/3 - 0s - 38ms/step - accuracy: 0.9583 - loss: 0.1117 - val_accuracy: 0.9583 - val_loss: 0.1752
# Epoch 198/200
#
# Epoch 198: val_loss improved from 0.17522 to 0.17464, saving model to best_model_iris.keras
# 3/3 - 0s - 39ms/step - accuracy: 0.9583 - loss: 0.1107 - val_accuracy: 0.9583 - val_loss: 0.1746
# Epoch 199/200
#
# Epoch 199: val_loss did not improve from 0.17464
# 3/3 - 0s - 30ms/step - accuracy: 0.9583 - loss: 0.1101 - val_accuracy: 0.9583 - val_loss: 0.1750
# Epoch 200/200
#
# Epoch 200: val_loss did not improve from 0.17464
# 3/3 - 0s - 31ms/step - accuracy: 0.9583 - loss: 0.1096 - val_accuracy: 0.9583 - val_loss: 0.1757
# Restoring model weights from the end of the best epoch: 198.

# %% [markdown]
# ### ✅ Evaluate and Visualize

# %%
# Predict
y_pred_full_3 = np.argmax(model_full_3.predict(X_test_f), axis=1)

# Accuracy and confusion matrix
print("Accuracy (All Features MLP):", accuracy_score(y_true_full, y_pred_full_3))

ConfusionMatrixDisplay(confusion_matrix(y_true_full, y_pred_full_3), display_labels=target_names).plot()
plt.title("Confusion Matrix – MLP with All 4 Features")
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001FBD07D62A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Accuracy (All Features MLP): 1.0

# %% [markdown]
# ### ✅ Load Best Model and Evaluate

# %%
best_model = load_model('best_model_iris.keras')

y_pred_best = np.argmax(best_model.predict(X_test_f), axis=1)
print("Accuracy of Best Saved Model:", accuracy_score(y_true_full, y_pred_best))
ConfusionMatrixDisplay(confusion_matrix(y_true_full, y_pred_best), display_labels=target_names).plot()
plt.title("Confusion Matrix – Best Saved Model")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Accuracy of Best Saved Model: 1.0

# %%
# Out:
# (30, 4)
